# %%
"father":
[
    {"John":"William","Emma","David","Olivia","Adam","Lily"},
    {"William":"Chris","Stephanie"},
    {"David":"Wayne","Tiffany","Julie","Neil","Peter"},
    {"Adam":"Sophia"}
]
 "mother":
 [
     {"Megan":"William","Emma","David","Olivia","Adam","Lily"},
     {"Emma":"Chris","Stephanie"},
     {"Olivia":"Wayne","Tiffany","Julie","Neil","Peter"},
     {"Lily":"Sophia"}
 ]
 "siblings":
 [
     {"Chris":"Stephanie"},
     {"Wayne":"Tiffany","Julie","Neil","Peter"}
 ]
 "uncle":
 [
     {"William":"Wayne","Tiffany","Julie","Neil","Peter","Sophia"},
     {"David":"Chris","Stephanie","Sophia"},
     {"Adam":"Wayne","Tiffany","Julie","Neil","Peter","Sophia","Chris","Stephanie"}
 ]
 "aunt":
 [
     {"Emma":"Wayne","Tiffany","Julie","Neil","Peter","Sophia"},
     {"Olivia":"Chris","Stephanie","Sophia"},
     {"Lily":"Wayne","Tiffany","Julie","Neil","Peter","Sophia","Chris","Stephanie"}
 ]
 "grandfather":
 [
     {"John":"Chris","Wayne","Tiffany","Julie","Neil","Peter","Sophia"}
 ]
 "grandmother":
 [
     {"Megan":"Chris","Wayne","Tiffany","Julie","Neil","Peter","Sophia"}
 ]

print(relation("William","Emma"))
# Out:
#   File "<ipython-input-1-2f2956a09bab>", line 2
#     "father":
#              ^
# SyntaxError: invalid syntax

# %%
"father":
[
    {"John":"William","Emma","David","Olivia","Adam","Lily"},
    {"William":"Chris","Stephanie"},
    {"David":"Wayne","Tiffany","Julie","Neil","Peter"},
    {"Adam":"Sophia"}
]
 "mother":
 [
     {"Megan":"William","Emma","David","Olivia","Adam","Lily"},
     {"Emma":"Chris","Stephanie"},
     {"Olivia":"Wayne","Tiffany","Julie","Neil","Peter"},
     {"Lily":"Sophia"}
 ]
 "siblings":
 [
     {"Chris":"Stephanie"},
     {"Wayne":"Tiffany","Julie","Neil","Peter"}
 ]
 "uncle":
 [
     {"William":"Wayne","Tiffany","Julie","Neil","Peter","Sophia"},
     {"David":"Chris","Stephanie","Sophia"},
     {"Adam":"Wayne","Tiffany","Julie","Neil","Peter","Sophia","Chris","Stephanie"}
 ]
 "aunt":
 [
     {"Emma":"Wayne","Tiffany","Julie","Neil","Peter","Sophia"},
     {"Olivia":"Chris","Stephanie","Sophia"},
     {"Lily":"Wayne","Tiffany","Julie","Neil","Peter","Sophia","Chris","Stephanie"}
 ]
 "grandfather":
 [
     {"John":"Chris","Wayne","Tiffany","Julie","Neil","Peter","Sophia"}
 ]
 "grandmother":
 [
     {"Megan":"Chris","Wayne","Tiffany","Julie","Neil","Peter","Sophia"}
 ]

print(relation("William","Emma"))

# %%
grandParent = ['john', 'megan']
parent1 = ['william', 'emma']
parent2 = ['david', 'olivia']
parent3 = ['adam', 'lily']
children1 = ['chris', 'stephanie']
children2 = ['wayne', 'tiffany', 'julie', 'neil', 'peter']
children3 = ['sophia']

def Relation(name1, name2):
    
    if name1 in grandParent:
        if name2 in grandParent:
            print(name1, name2, "are husband-wife")
        elif name2 in parent1 or name2 in parent2 or name2 in parent3:
            print(name1, name2, "are parent and child")
        else:
            print(name1, name2, "are grandparent and grandchild")
    
    elif name1 in parent1:
        if name2 in grandParent:
            print(name1, name2, "are child and parent")
        elif name2 in parent1:
            print(name1, name2, "are husband-wife")
        elif name2 in parent2 or name2 in parent3:
            print(name1, name2, "are siblings")
        elif name2 in children1:
            print(name1, name2, "are parent and child")
        else:
            print(name1, name2, "are uncle/nephew and niece/nephew")

    elif name1 in parent2:
        if name2 in grandParent:
            print(name1, name2, "are child and parent")
        elif name2 in parent2:
            print(name1, name2, "are husband-wife")
        elif name2 in parent1 or name2 in parent3:
            print(name1, name2, "are siblings")
        elif name2 in children2:
            print(name1, name2, "are parent and child")
        else:
            print(name1, name2, "are uncle/nephew and niece/nephew")

    elif name1 in parent3:
        if name2 in grandParent:
            print(name1, name2, "are child and parent")
        elif name2 in parent3:
            print(name1, name2, "are husband-wife")
        elif name2 in parent1 or name2 in parent2:
            print(name1, name2, "are siblings")
        elif name2 in children3:
            print(name1, name2, "are parent and child")
        else:
            print(name1, name2, "are uncle/nephew and niece/nephew")

    elif name1 in children1:
        if name2 in grandParent:
            print(name1, name2, "are grandchild and grandparent")
        elif name2 in parent1:
            print(name1, name2, "are child and parent")
        elif name2 in parent2 or name2 in parent3:
            print(name1, name2, "are niece/nephew and uncle/aunt")
        elif name2 in children1:
            print(name1, name2, "are siblings")
        else:
            print(name1, name2, "are cousins")

    elif name1 in children2:
        if name2 in grandParent:
            print(name1, name2, "are grandchild and grandparent")
        elif name2 in parent2:
            print(name1, name2, "are child and parent")
        elif name2 in parent1 or name2 in parent3:
            print(name1, name2, "are niece/nephew and uncle/aunt")
        elif name2 in children2:
            print(name1, name2, "are siblings")
        else:
            print(name1, name2, "are cousins")

    elif name1 in children3:
        if name2 in grandParent:
            print(name1, name2, "are grandchild and grandparent")
        elif name2 in parent3:
            print(name1, name2, "are child and parent")
        elif name2 in parent1 or name2 in parent2:
            print(name1, name2, "are niece/nephew and uncle/aunt")
        elif name2 in children3:
            print(name1, name2, "are siblings")
        else:
            print(name1, name2, "are cousins")

useName1 = str(input("Enter first name: "))
useName2 = str(input("Enter second name: "))

Relation(useName1, useName2)
# Out:
# Enter first name: david
# Enter second name: olivia
# david olivia are spouses
