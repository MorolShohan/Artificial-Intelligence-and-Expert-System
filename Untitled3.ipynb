# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Draw a line.')
plt.show()

# %%
x=int(input("Enter the number of steps : "))
for i in range(x):
  print("1. [A, Clean]")
  print("2. [A, Dirty]")
  print("3. [B, Clean]")
  print("4. [B, Dirty]")
  option=int(input("Choose an option: "))
  if option==1:
    print("Action is Right")
  elif option==2:
    print("Action is Suck")
  elif option==3:
    print("Action is Left")
  elif option==4:
    print("Action is Suck")
print("\nThe End!")
