# %%
a='old'
b=' tree'
c=a+b
print(c)
# Out:
# old tree

# %%
a='rad'
a+='shahamat'
a+='akash'
print(a)

# %%
for i in range(1,100)
for num in range(start, end +1):
    if num % 2 != 0:
        print(num)
# Out:
#   File "<ipython-input-14-99eb62207a1f>", line 1
#     for i in range(1,100)
#                          ^
# SyntaxError: invalid syntax
